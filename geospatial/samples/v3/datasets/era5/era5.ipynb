# %% [markdown]
# # ERA5 Global weather

# %% [markdown]
# <b>Table of Contents</b>
#
# - Overview
# - Setup
#     - Get authentication token
# - Data layers
# - Querying the data layers
#     - Point query
#     - Raster query
# - References

# %% [markdown]
# ## Overview
#
# As any reanalysis product, ERA5 combines observed data with the output of meteorological models. Note that there are actually two versions of ERA5 data. Initial data is referred to as ERA5T and available in near real time. I.e., ERA5T data lags real time by about three days. About three months later, the final version of the data is released. This is the actual ERA5 data. This Data Set contains both ERA5 and ERA5T data. With the latter being uploaded initially and overwritten once the former is available. As far as currently known, differences between the two versions are negligible. The Data Set contains data for 1980, 1990, 2000, 2005 and from 2009 onwards.
#
# Let us get a practical understanding about this Data Set and its usage through this tutorial.

# %% [markdown]
# ## Setup
#
# Before starting, you have to install IBM EI Geospatial python SDK i.e ibmpairs and other modules needed to run this sample, mentioned in the cell below.
#
# <b>Note:</b> To run this notebook seamlessly, you have to first configure your Geospatial APIs' credentials in a file named `secrets.ini` in the below format:
#
# ```
# [EI]
# api.api_key = <Your Geospatial APIs API key>
# api.tenant_id = <Your Geospatial APIs Tenant ID>
# api.org_id = <Your Geospatial APIs Org ID>
# ```
#
# Keep the secrets.ini file at an appropriate relative location of this notebook. For example, as specified in the config below.
#
# ```config.read('../../../../auth/secrets.ini')```

# %%
# %pip install ibmpairs
# %pip install configparser
# %pip install matplotlib
# %pip install ipyplot

# %%
import ibmpairs.client as client
import ibmpairs.catalog as catalog
import ibmpairs.query as query
import pandas as pd
import configparser
import json
import numpy as np
from PIL import Image as PILImage
from IPython.display import Image, display
import matplotlib.pyplot as plt
import os
import ipyplot

# %% [markdown]
# Now, let us create a client object using the API_KEY, TENANT_ID (or CLIENT_ID) and ORG_ID to create an authenticated HTTP client Authentication token using 'ibmpairs.client' module, to use it in the subsequent steps.
#
# ### Get authentication token

# %%
config = configparser.RawConfigParser()
config.read('../../../../auth/secrets.ini')
# Best practice is not to include secrets in source code so we read
# an api key, tenant id and org id from a secrets.ini file.
# You could set the credentials in-line here but we don't
# recommend it for security reasons.

EI_API_KEY    = config.get('EI', 'api.api_key')
EI_TENANT_ID  = config.get('EI', 'api.tenant_id') 
EI_ORG_ID     = config.get('EI', 'api.org_id')  

EI_client_v3  = client.get_client(api_key   = EI_API_KEY,
                                    tenant_id = EI_TENANT_ID,
                                    org_id    = EI_ORG_ID,
                                    legacy    = False,
                                    version   = 3
                                   )
# Out:
# 2025-01-22 10:58:57 - paw - INFO - The client authentication method is assumed to be OAuth2.
# 2025-01-22 10:58:57 - paw - INFO - Legacy Environment is False
# 2025-01-22 10:58:57 - paw - INFO - The authentication api key type is assumed to be IBM EIS, because the api key prefix 'PHX' is present.
# 2025-01-22 10:58:59 - paw - INFO - Authentication success.
# 2025-01-22 10:58:59 - paw - INFO - HOST: https://api.ibm.com/geospatial/run/na/core/v3

# %% [markdown]
# ## Data layers
#
# Let us start by querying the ibmpairs catalog to retrieve the Data Set ID and the Data Layers that form the Data Set.

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
search_df=catalog.search("ERA5 Global weather")
search_df[['dataset_id','data_layer_id','data_layer_name','data_layer_description_short',
           'data_layer_level','data_layer_type','data_layer_unit','data_set_name','data_set_description_short']]
# Out:
#    dataset_id data_layer_id  \
# 0         190         49417
# 1         190         49418
# 2         190         49419
# 3         190         49420
# 4         190         49421
# 5         190         49422
# 6         190         49423
# 7         190         49424
# 8         190         49434
# 9         190         49425
# 10        190         49426
# 11        190         49427
# 12        190         49428
# 13        190         49429
# 14        190         49430
# 15        190         49432
# 16        190         49433
# 17        190         49435
# 18        190         49436
# 19        190         49437
# 20        190         49438
# 21        190         49439
# 22        190         49440
# 23        190         49441
# 24        190         49442
# 25        190         49443
# 26        190         49444
# 27        190         49445
# 28        190         49446
# 29        190         49447
# 30        190         49448
# 31        190         49450
# 32        190         49451
# 33        190         49452
# 34        190         49453
# 35        190         49454
# 36        190         49455
# 37        190         49456
# 38        190         49457
# 39        190         49458
# 40        190         49459
# 41        190         49460
# 42        190         49461
# 43        190         49462
# 44        190         49463
# 45        190         50056
# 46        190         50057
# 47        190         50058
# 48        190         50444
# 49        190         50445
# 50        190         50446
# 51        190         50447
# 52        190         50448
# 53        190         50449
# 54        190         50450
# 55        190         50451
# 56        190         50452
# 57        190         50453
# 58        190         50454
# 59        190         50455
# 60        190         50456
# 61        190         50457
#
#                                       data_layer_name  \
# 0                         100 meter wind towards east
# 1                        100 meter wind towards north
# 2                        10 meter wind gust (maximum)
# 3                          10 meter wind towards east
# 4                         10 meter wind towards north
# 5                                            Dewpoint
# 6                                         Temperature
# 7                         Solar radiation (total sky)
# 8                             Mean sea level pressure
# 9                                    High cloud cover
# 10                 10 meter wind gust (instantaneous)
# 11                                    Low cloud cover
# 12                                 Medium cloud cover
# 13                                Minimum temperature
# 14                                Maximum temperature
# 15                         Minimum precipitation rate
# 16                         Maximum precipitation rate
# 17                                 Precipitation type
# 18                                       Snow density
# 19                                         Snow depth
# 20                                           Snowfall
# 21                                   Surface pressure
# 22                                    Solar radiation
# 23                        Solar radiation (clear sky)
# 24                            Sea surface temperature
# 25                       Soil temperature (0 to 7 cm)
# 26                      Soil temperature (7 to 21 cm)
# 27                     Soil temperature (21 to 72 cm)
# 28                    Soil temperature (72 to 189 cm)
# 29                                  Thermal radiation
# 30                      Thermal radiation (clear sky)
# 31                             Soil water (0 to 7 cm)
# 32                            Soil water (7 to 21 cm)
# 33                           Soil water (21 to 72 cm)
# 34                          Soil water (72 to 189 cm)
# 35                                  Total cloud cover
# 36                   Rain water content of atmosphere
# 37                   Snow water content of atmosphere
# 38                          Atmospheric water content
# 39                    Atmospheric water vapor content
# 40                                Total precipitation
# 41                Solar radiation (top of atmosphere)
# 42    Solar radiation (top of atmosphere) (clear sky)
# 43              Thermal radiation (top of atmosphere)
# 44  Thermal radiation (top of atmosphere) (clear sky)
# 45                                        Wave height
# 46                                     Wave direction
# 47                                        Wave period
# 48                                         Lake cover
# 49                                         Lake depth
# 50                               Low vegetation cover
# 51                              High vegetation cover
# 52                             Type of low vegetation
# 53                            Type of high vegetation
# 54                                          Soil type
# 55      Sub grid scale elevation (standard deviation)
# 56                     Gravitational potential energy
# 57                    Standard deviation of orography
# 58             Anisotropy of sub grid scale orography
# 59                  Angle of sub grid scale orography
# 60                  Slope of sub grid scale orography
# 61                                      Land sea mask
#
#                                                                        data_layer_description_short  \
# 0                         The short name of this parameter (as used in the raw GRIB files) is 100u.
# 1                         The short name of this parameter (as used in the raw GRIB files) is 100v.
# 2                         The short name of this parameter (as used in the raw GRIB files) is 10fg.
# 3                          The short name of this parameter (as used in the raw GRIB files) is 10u.
# 4                          The short name of this parameter (as used in the raw GRIB files) is 10v.
# 5                           The short name of this parameter (as used in the raw GRIB files) is 2d.
# 6                           The short name of this parameter (as used in the raw GRIB files) is 2t.
# 7                         The short name of this parameter (as used in the raw GRIB files) is fdir.
# 8                          The short name of this parameter (as used in the raw GRIB files) is msl.
# 9                          The short name of this parameter (as used in the raw GRIB files) is hcc.
# 10                       The short name of this parameter (as used in the raw GRIB files) is i10fg.
# 11                         The short name of this parameter (as used in the raw GRIB files) is lcc.
# 12                         The short name of this parameter (as used in the raw GRIB files) is mcc.
# 13                        The short name of this parameter (as used in the raw GRIB files) is mn2t.
# 14                        The short name of this parameter (as used in the raw GRIB files) is mx2t.
# 15                       The short name of this parameter (as used in the raw GRIB files) is mntpr.
# 16                       The short name of this parameter (as used in the raw GRIB files) is mxtpr.
# 17                       The short name of this parameter (as used in the raw GRIB files) is ptype.
# 18                         The short name of this parameter (as used in the raw GRIB files) is rsn.
# 19                          The short name of this parameter (as used in the raw GRIB files) is sd.
# 20                          The short name of this parameter (as used in the raw GRIB files) is sf.
# 21                          The short name of this parameter (as used in the raw GRIB files) is sp.
# 22                        The short name of this parameter (as used in the raw GRIB files) is ssrd.
# 23                       The short name of this parameter (as used in the raw GRIB files) is ssrdc.
# 24                         The short name of this parameter (as used in the raw GRIB files) is sst.
# 25                        The short name of this parameter (as used in the raw GRIB files) is stl1.
# 26                        The short name of this parameter (as used in the raw GRIB files) is stl2.
# 27                        The short name of this parameter (as used in the raw GRIB files) is stl3.
# 28                        The short name of this parameter (as used in the raw GRIB files) is stl4.
# 29                        The short name of this parameter (as used in the raw GRIB files) is strd.
# 30                       The short name of this parameter (as used in the raw GRIB files) is strdc.
# 31                       The short name of this parameter (as used in the raw GRIB files) is swvl1.
# 32                       The short name of this parameter (as used in the raw GRIB files) is swvl2.
# 33                       The short name of this parameter (as used in the raw GRIB files) is swvl3.
# 34                       The short name of this parameter (as used in the raw GRIB files) is swvl4.
# 35                         The short name of this parameter (as used in the raw GRIB files) is tcc.
# 36                        The short name of this parameter (as used in the raw GRIB files) is tcrw.
# 37                        The short name of this parameter (as used in the raw GRIB files) is tcsw.
# 38                         The short name of this parameter (as used in the raw GRIB files) is tcw.
# 39                        The short name of this parameter (as used in the raw GRIB files) is tcwv.
# 40                          The short name of this parameter (as used in the raw GRIB files) is tp.
# 41                         The short name of this parameter (as used in the raw GRIB files) is tsr.
# 42                        The short name of this parameter (as used in the raw GRIB files) is tsrc.
# 43                         The short name of this parameter (as used in the raw GRIB files) is ttr.
# 44                        The short name of this parameter (as used in the raw GRIB files) is ttrc.
# 45      Average height of the highest third of surface ocean/sea waves generated by wind and swell.
# 46                                                       Mean direction of ocean/sea surface waves.
# 47              Average time it takes for two consecutive wave crests to pass through a fixed point
# 48                          The short name of this parameter (as used in the raw GRIB files) is cl.
# 49                          The short name of this parameter (as used in the raw GRIB files) is dl.
# 50                         The short name of this parameter (as used in the raw GRIB files) is cvl.
# 51                         The short name of this parameter (as used in the raw GRIB files) is cvh.
# 52                         The short name of this parameter (as used in the raw GRIB files) is tvl.
# 53                         The short name of this parameter (as used in the raw GRIB files) is tvh.
# 54                         The short name of this parameter (as used in the raw GRIB files) is slt.
# 55                       The short name of this parameter (as used in the raw GRIB files) is sdfor.
# 56  Also known as orography. The short name of this parameter (as used in the raw GRIB files) is z.
# 57                        The short name of this parameter (as used in the raw GRIB files) is sdor.
# 58                        The short name of this parameter (as used in the raw GRIB files) is isor.
# 59                        The short name of this parameter (as used in the raw GRIB files) is anor.
# 60                        The short name of this parameter (as used in the raw GRIB files) is slor.
# 61                         The short name of this parameter (as used in the raw GRIB files) is lsm.
#
#     data_layer_level data_layer_type data_layer_unit        data_set_name  \
# 0                 12          Raster           m s-1  ERA5 Global weather
# 1                 12          Raster           m s-1  ERA5 Global weather
# 2                 12          Raster           m s-1  ERA5 Global weather
# 3                 12          Raster           m s-1  ERA5 Global weather
# 4                 12          Raster           m s-1  ERA5 Global weather
# 5                 12          Raster               K  ERA5 Global weather
# 6                 12          Raster               K  ERA5 Global weather
# 7                 12          Raster           J m-2  ERA5 Global weather
# 8                 12          Raster              Pa  ERA5 Global weather
# 9                 12          Raster           [0-1]  ERA5 Global weather
# 10                12          Raster                  ERA5 Global weather
# 11                12          Raster           [0-1]  ERA5 Global weather
# 12                12          Raster           [0-1]  ERA5 Global weather
# 13                12          Raster               K  ERA5 Global weather
# 14                12          Raster               K  ERA5 Global weather
# 15                12          Raster      kg m-2 s-1  ERA5 Global weather
# 16                12          Raster      kg m-2 s-1  ERA5 Global weather
# 17                12          Raster           [0-8]  ERA5 Global weather
# 18                12          Raster          kg m-3  ERA5 Global weather
# 19                12          Raster  m water equiv.  ERA5 Global weather
# 20                12          Raster  m water equiv.  ERA5 Global weather
# 21                12          Raster              Pa  ERA5 Global weather
# 22                12          Raster           J m-2  ERA5 Global weather
# 23                12          Raster           J m-2  ERA5 Global weather
# 24                12          Raster               K  ERA5 Global weather
# 25                12          Raster               K  ERA5 Global weather
# 26                12          Raster               K  ERA5 Global weather
# 27                12          Raster               K  ERA5 Global weather
# 28                12          Raster               K  ERA5 Global weather
# 29                12          Raster                  ERA5 Global weather
# 30                12          Raster                  ERA5 Global weather
# 31                12          Raster          m3 m-3  ERA5 Global weather
# 32                12          Raster          m3 m-3  ERA5 Global weather
# 33                12          Raster          m3 m-3  ERA5 Global weather
# 34                12          Raster          m3 m-3  ERA5 Global weather
# 35                12          Raster           [0-1]  ERA5 Global weather
# 36                12          Raster          kg m-2  ERA5 Global weather
# 37                12          Raster          kg m-2  ERA5 Global weather
# 38                12          Raster          kg m-2  ERA5 Global weather
# 39                12          Raster          kg m-2  ERA5 Global weather
# 40                12          Raster               m  ERA5 Global weather
# 41                12          Raster           J m-2  ERA5 Global weather
# 42                12          Raster           J m-2  ERA5 Global weather
# 43                12          Raster           J m-2  ERA5 Global weather
# 44                12          Raster           J m-2  ERA5 Global weather
# 45                10          Raster               m  ERA5 Global weather
# 46                10          Raster     Degree true  ERA5 Global weather
# 47                10          Raster               s  ERA5 Global weather
# 48                12          Raster                  ERA5 Global weather
# 49                12          Raster                  ERA5 Global weather
# 50                12          Raster                  ERA5 Global weather
# 51                12          Raster                  ERA5 Global weather
# 52                12          Raster                  ERA5 Global weather
# 53                12          Raster                  ERA5 Global weather
# 54                12          Raster                  ERA5 Global weather
# 55                12          Raster                  ERA5 Global weather
# 56                12          Raster                  ERA5 Global weather
# 57                12          Raster                  ERA5 Global weather
# 58                12          Raster                  ERA5 Global weather
# 59                12          Raster                  ERA5 Global weather
# 60                12          Raster                  ERA5 Global weather
# 61                12          Raster                  ERA5 Global weather
#
#                                                                                                                                      data_set_description_short
# 0   Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 1   Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 2   Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 3   Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 4   Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 5   Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 6   Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 7   Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 8   Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 9   Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 10  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 11  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 12  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 13  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 14  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 15  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 16  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 17  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 18  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 19  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 20  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 21  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 22  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 23  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 24  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 25  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 26  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 27  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 28  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 29  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 30  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 31  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 32  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 33  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 34  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 35  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 36  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 37  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 38  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 39  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 40  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 41  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 42  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 43  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 44  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 45  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 46  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 47  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 48  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 49  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 50  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 51  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 52  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 53  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 54  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 55  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 56  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 57  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 58  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 59  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 60  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.
# 61  Reanalysis produced by the European Centre for Medium-Range Weather Forecasts (ECMWF) that combines observed data with the output of meteorological models.

# %% [markdown]
# As seen above, the ERA5 Global weather Data Set of ID 190 has sixty two Data Layers. This collection of Data Layers defines atmospheric, ocean-wave and land-surface variations. Each of the Data Layers are identified by a unique Data Layer ID. To gain a better understanding of the Data Set and its geospatial and temporal coverage as well as other relevant metadata, we can make further queries to the ibmpairs catalog submodule as mentioned in the [tutorials](https://ibm.github.io/ibmpairs/tutorials/quickstart/quickstartcatalog.html).

# %% [markdown]
# ## Querying the data layers
#
# Given the large number of data layers in this data set, we will focus on selecting specific layers of interest for our queries.
#
#
# ### Point query
#
# Next, we shall perform a point query for different locations to observe values for various quantities of the ERA5 Global weather Data Set.

# %%
query_result = query.submit(
    {
        "layers": [
            {
              "type": "raster",
              "id": "49417", #100 meter wind towards east
            },
            {
              "type": "raster",
              "id": "49422", #Dewpoint
            },
            {
              "type": "raster",
              "id": "49450", #Soil water
            },
            {
              "type": "raster",
              "id": "49457", #Atmospheric water content
            },
            {
              "type": "raster",
              "id": "49438", #Snowfall
            },
            {
              "type": "raster",
              "id": "49459", #Total precipitation
            },
            {
              "type": "raster",
              "id": "49423", #Temperature
            }
        ],
        "spatial": {
            "type": "point",
            "coordinates": [
                19.4139, -70.3168, 
                13.8753, -60.9865
            ]
        },
        "temporal": {
            "intervals": [
                {
                    "start": "2024-01-15T00:00:00Z",
                    "end": "2024-01-15T05:00:00Z"
                }
            ]
        }
    }, client=EI_client_v3)
# Convert the results to a dataframe
point_df = query_result.point_data_as_dataframe()
point_df['value'] = point_df['value'].apply(lambda x: '{:.6f}'.format(float(x)))
point_df['datetime'] = pd.to_datetime(point_df['timestamp'] , unit='ms', errors = 'coerce')
point_df['datetime'] = point_df['datetime'].dt.strftime('%Y-%m-%dT%H:%M:%SZ')
# 66   13.8753   34.394188  2024-01-15T03:00:00Z
# 67   19.4139   24.435537  2024-01-15T03:00:00Z
# 68   13.8753   33.918385  2024-01-15T04:00:00Z
# 69   19.4139   24.324448  2024-01-15T04:00:00Z
# 70   13.8753   33.277367  2024-01-15T05:00:00Z
# 71   19.4139   24.141130  2024-01-15T05:00:00Z
# 72   13.8753    0.000000  2024-01-15T00:00:00Z
# 73   19.4139    0.000003  2024-01-15T00:00:00Z
# 74   13.8753    0.000001  2024-01-15T01:00:00Z
# 75   19.4139    0.000003  2024-01-15T01:00:00Z
# 76   13.8753    0.000009  2024-01-15T02:00:00Z
# 77   19.4139    0.000002  2024-01-15T02:00:00Z
# 78   13.8753    0.000013  2024-01-15T03:00:00Z
# 79   19.4139    0.000002  2024-01-15T03:00:00Z
# 80   13.8753    0.000012  2024-01-15T04:00:00Z
# 81   19.4139    0.000002  2024-01-15T04:00:00Z
# 82   13.8753    0.000013  2024-01-15T05:00:00Z
# 83   19.4139    0.000001  2024-01-15T05:00:00Z

# %% [markdown]
# We see above, that various quantity values are obtained for various Data Layers with their respective locations we queried for. For instance, the locations we queried for Data Layer `Dewpoint` with Data Layer ID as `49422` has a value for 6hrs (hourly values) for the temporal date interval range defined in the query.

# %% [markdown]
# ### Raster query
#
# Next, we shall make a raster query for a square area and observe the outcome for some of the Data Layers of this Data Set.

# %%
era5_result = query.submit_check_status_and_download(
    {
        "publish": True,
        "name": "ERA5 Global weather Raster Query",
        "spatial": {
            "type": "square",
            "coordinates": [47.975, 64.66, 67.806, 103.343]
        },
        "temporal": {
            "intervals": [
                {
                    "start": "2024-01-15T00:00:00Z",
                    "end": "2024-01-15T01:00:00Z"
                }
            ]
        },
        "layers": [
            {
              "type": "raster",
              "id": "49417", #100 meter wind towards east
            },
            {
              "type": "raster",
              "id": "49422", #Dewpoint
            },
            {
              "type": "raster",
              "id": "49450", #Soil water
            },
            {
              "type": "raster",
              "id": "49457", #Atmospheric water content
            },
            {
              "type": "raster",
              "id": "49438", #Snowfall
            },
            {
              "type": "raster",
              "id": "49459", #Total precipitation
            },
            {
              "type": "raster",
              "id": "49423", #Temperature
            }
        ]
    }, client=EI_client_v3)
# Out:
# 2025-01-22 11:00:05 - paw - INFO - TASK: submit_check_status_and_download STARTING.
# 2025-01-22 11:00:07 - paw - INFO - The query was successfully submitted with the id: 1737504000_19807107.
# 2025-01-22 11:00:08 - paw - INFO - The query 1737504000_19807107 has the status Queued.
# 2025-01-22 11:00:39 - paw - INFO - The query 1737504000_19807107 has the status Running.
# 2025-01-22 11:01:10 - paw - INFO - The query 1737504000_19807107 has the status Succeeded.
# 2025-01-22 11:01:10 - paw - INFO - The query 1737504000_19807107 was successful after checking the status.
# 2025-01-22 11:01:41 - paw - INFO - The query 1737504000_19807107 has the status Succeeded.
# 2025-01-22 11:01:41 - paw - INFO - The query 1737504000_19807107 was successful after checking the status.
# 2025-01-22 11:01:41 - paw - WARNING - The query download folder download was not present on the operating system as either a fixed or relative path. Attempting to create.
# 2025-01-22 11:01:41 - paw - INFO - The query download folder is set to the path /Users/environmental-intelligence/Environmental-Intelligence-internal/geospatial/samples/v3/datasets/era5/download/.
# 2025-01-22 11:01:41 - paw - INFO - The query download folder /Users/environmental-intelligence/Environmental-Intelligence-internal/geospatial/samples/v3/datasets/era5/download/ was successfully created.
# 2025-01-22 11:02:05 - paw - INFO - The query 1737504000_19807107 is a zip.
# 2025-01-22 11:02:05 - paw - INFO - The query file for 1737504000_19807107 will be downloaded to the following path /Users/environmental-intelligence/Environmental-Intelligence-internal/geospatial/samples/v3/datasets/era5/download/1737504000_19807107.zip.
# 2025-01-22 11:02:05 - paw - INFO - The query file for 1737504000_19807107 was successfully downloaded to /Users/environmental-intelligence/Environmental-Intelligence-internal/geospatial/samples/v3/datasets/era5/download/1737504000_19807107.zip.
# 2025-01-22 11:02:05 - paw - INFO - The query zip /Users/environmental-intelligence/Environmental-Intelligence-internal/geospatial/samples/v3/datasets/era5/download/1737504000_19807107.zip will be unzipped to the following path /Users/environmental-intelligence/Environmental-Intelligence-internal/geospatial/samples/v3/datasets/era5/download/1737504000_19807107.
# 2025-01-22 11:02:05 - paw - INFO - The query zip /Users/environmental-intelligence/Environmental-Intelligence-internal/geospatial/samples/v3/datasets/era5/download/1737504000_19807107.zip was successfully unzipped to /Users/environmental-intelligence/Environmental-Intelligence-internal/geospatial/samples/v3/datasets/era5/download/1737504000_19807107.
# 2025-01-22 11:02:35 - paw - INFO - TASK: submit_check_status_and_download COMPLETED.

# %% [markdown]
# The query takes a few seconds to complete and downloads the output as a zip file in the /download folder within the same location as this notebook. Now we shall display the resultant tiff using the following utility function.

# %%
# Function to display the resulting Tiff(s).
era5_file_list = era5_result.list_files()
output_image_array = []
for file in era5_file_list:
    if file.endswith('.tiff'): #display the raster images
        with open(file+'.json', 'r') as summary_file:
            fileparms = json.load(summary_file)
        boundingBox=fileparms["boundingBox"]
        pixelStatistics=fileparms["rasterStatistics"]
        myextent=[boundingBox["minLongitude"],
                  boundingBox["maxLongitude"],
                  boundingBox["minLatitude"],
                  boundingBox["maxLatitude" ] ]  
        array_era5 = np.array(PILImage.open(file))
        mask = (array_era5 == -9999)
        # Masked array to exclude NO Data points from plotting
        masked_array = np.ma.masked_array(array_era5, mask)
        plt.figure(figsize = (20, 9), dpi=80) # Sets the size and resolution of the plot
        plt.imshow(masked_array,
                   cmap = 'terrain', 
                   vmin=pixelStatistics["pixelMin"], 
                   vmax=pixelStatistics["pixelMax"],
                   extent = myextent) # Loads the raster data and sets the colormap
        plt.colorbar() # Adds the color bar
        plt.title(" "+os.path.basename(file)) 
        output_image_path = os.path.splitext(os.path.basename(file))[0] + ".png"
        output_image_array.append(output_image_path)
        # Save the figure
        plt.savefig(output_image_path, bbox_inches='tight')
        plt.close() 

for output_image in output_image_array:
    #display the raster images
    display(Image(output_image,width=800, height=400))

# %% [markdown]
# Each of the images above represents the variations of quantities like Dewpoint, Temperature, Total precipitation and others for the spatial location and temporal period. Each quantity captures information that can be used for different applications like weather monitoring etc.

# %% [markdown]
# ## References
# https://www.ecmwf.int/
#
# https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels
#
# https://en.wikipedia.org/wiki/Meteorological_reanalysis
#
# https://cds.climate.copernicus.eu
